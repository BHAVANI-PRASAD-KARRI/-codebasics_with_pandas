# %%
import pandas as pd
weather_data  = [
    {'day': '1/1/2026' , 'tempeature': 34 , 'windspeed': 6 ,'event':'Rain'},
    {'day': '1/2/2026' , 'tempeature': 35 , 'windspeed': 7 ,'event':'Sunny'},
    {'day': '1/3/2026' , 'tempeature': 28 , 'windspeed': 2 ,'event':'Snow'},
        
]
df = pd.DataFrame(weather_data)
df
# Out:
#         day  tempeature  windspeed  event
# 0  1/1/2026          34          6   Rain
# 1  1/2/2026          35          7  Sunny
# 2  1/3/2026          28          2   Snow

# %%
# 4:READING WEITING CSV ,EXCEL FILES
TOPICS:
 1.Read csv 
 2.Write csv
 3.Read excel
 4.Write excel

# %%
df = pd.read_csv("stock_data.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd . read_csv("stock_data.csv")
df
# Out:
#   stocks data     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0     tickers            eps    revenue      price         people
# 1       GOOGL          27.82         87        845     larry page
# 2         WMT           4.61        484         65           n.a.
# 3        MSFT             -1         85         64     bill gates
# 4        RIL   not available         50       1023  mukesh ambani
# 5        TATA            5.6         -1       n.a.     ratan tata

# %%
df = pd .read_csv("stock_data.csv",skip_rows=1)
df # skip_rows=1-------skiprows=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd .read_csv("stock_data.csv",skip_rows=1)
#       2 df
#
# TypeError: read_csv() got an unexpected keyword argument 'skip_rows'. Did you mean 'skiprows'?

# %%
df = pd .read_csv("stock_data.csv",skiprows=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd .read_csv("stock_data.csv",header=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd . read_csv ("stock_data.csv",header=None)
df
# Out:
#        0              1    2     3              4
# 0  GOOGL          27.82   87   845     larry page
# 1    WMT           4.61  484    65           n.a.
# 2   MSFT             -1   85    64     bill gates
# 3   RIL   not available   50  1023  mukesh ambani
# 4   TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd . read_csv ("stock_data.csv",header=None,name=["Ticker","Eps","Revenue","Price","People"])
df # name ---------names
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df = pd . read_csv ("stock_data.csv",header=None,name=["Ticker","Eps","Revenue","Price","People"])
#       2 df
#
# TypeError: read_csv() got an unexpected keyword argument 'name'. Did you mean 'names'?

# %%
df = pd . read_csv ("stock_data.csv",header=None,names=["Ticker","Eps","Revenue","Price","People"])
df                                                                         #6 mins
# Out:
#   Ticker            Eps  Revenue Price         People
# 0  GOOGL          27.82       87   845     larry page
# 1    WMT           4.61      484    65           n.a.
# 2   MSFT             -1       85    64     bill gates
# 3   RIL   not available       50  1023  mukesh ambani
# 4   TATA            5.6       -1  n.a.     ratan tata
